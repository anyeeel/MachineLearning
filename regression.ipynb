# %%
# Import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Anjel69\Desktop\machinelearning\Algerian_forest_fires_dataset.csv")
data
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
columns_to_drop = ['day', 'month', 'year', 'Ws', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI']
data = data.drop(columns=columns_to_drop, axis=1).dropna()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 columns_to_drop = ['day', 'month', 'year', 'Ws', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI']
# ----> 2 data = data.drop(columns=columns_to_drop, axis=1).dropna()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
# Drop unnecessary columns and handle missing values
columns_to_drop = ['day', 'month', 'year',Ws','FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI' ]
data = data.drop(columns=columns_to_drop, axis=1).dropna()
# Out:
#   Cell In[10], line 2
#     columns_to_drop = ['day', 'month', 'year',Ws','FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI' ]
#                                                                                         ^
# SyntaxError: unterminated string literal (detected at line 2)
